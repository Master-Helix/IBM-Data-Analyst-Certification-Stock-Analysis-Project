# %%
# FINAL ASSIGNMENT Done by RAKSHIT PANDEY

# %%
import yfinance as yf
tsla = yf.Ticker("TSLA")
tsla_data = tsla.history(period="max")
tsla_data.reset_index(inplace=True)
tsla_data
# Out:
#                           Date        Open        High         Low  \
# 0    2010-06-29 00:00:00-04:00    1.266667    1.666667    1.169333
# 1    2010-06-30 00:00:00-04:00    1.719333    2.028000    1.553333
# 2    2010-07-01 00:00:00-04:00    1.666667    1.728000    1.351333
# 3    2010-07-02 00:00:00-04:00    1.533333    1.540000    1.247333
# 4    2010-07-06 00:00:00-04:00    1.333333    1.333333    1.055333
# ...                        ...         ...         ...         ...
# 3714 2025-04-03 00:00:00-04:00  265.290009  276.299988  261.510010
# 3715 2025-04-04 00:00:00-04:00  255.380005  261.000000  236.000000
# 3716 2025-04-07 00:00:00-04:00  223.779999  252.000000  214.250000
# 3717 2025-04-08 00:00:00-04:00  245.000000  250.440002  217.800003
# 3718 2025-04-09 00:00:00-04:00  224.690002  274.690002  223.880005
#
#            Close     Volume  Dividends  Stock Splits
# 0       1.592667  281494500        0.0           0.0
# 1       1.588667  257806500        0.0           0.0
# 2       1.464000  123282000        0.0           0.0
# 3       1.280000   77097000        0.0           0.0
# 4       1.074000  103003500        0.0           0.0
# ...          ...        ...        ...           ...
# 3714  267.279999  136174300        0.0           0.0
# 3715  239.429993  181229400        0.0           0.0
# 3716  233.289993  183453800        0.0           0.0
# 3717  221.860001  171603500        0.0           0.0
# 3718  272.200012  218067600        0.0           0.0
#
# [3719 rows x 8 columns]

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/revenue.htm"
html_data = requests.get(url).text
soup = BeautifulSoup(html_data, "html.parser")

tables = soup.find_all("tbody")[1]
rows = tables.find_all("tr")

tesla_revenue = pd.DataFrame(columns=["Date", "Revenue"])

for row in rows:
    col = row.find_all("td")
    if col:
        date = col[0].text.strip()
        revenue = col[1].text.strip()

        new_row = pd.DataFrame([{"Date": date, "Revenue": revenue}])
        tesla_revenue = pd.concat([tesla_revenue, new_row], ignore_index=True)
        
tesla_revenue["Revenue"] = tesla_revenue['Revenue'].str.replace(',|\$',"")
tesla_revenue.dropna(inplace=True)

tesla_revenue = tesla_revenue[tesla_revenue['Revenue'] != ""]
tesla_revenue.tail()
# Out:
# <>:23: SyntaxWarning: invalid escape sequence '\$'
# <>:23: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\raksh\AppData\Local\Temp\ipykernel_12304\4252518235.py:23: SyntaxWarning: invalid escape sequence '\$'
#   tesla_revenue["Revenue"] = tesla_revenue['Revenue'].str.replace(',|\$',"")
#           Date Revenue
# 48  2010-09-30     $31
# 49  2010-06-30     $28
# 50  2010-03-31     $21
# 52  2009-09-30     $46
# 53  2009-06-30     $27

# %%
import yfinance as yf
gme = yf.Ticker("GME")
gme_data = gme.history(period="max")
gme_data.reset_index(inplace=True)
gme_data
# Out:
#                           Date       Open       High        Low      Close  \
# 0    2002-02-13 00:00:00-05:00   1.620128   1.693350   1.603296   1.691666
# 1    2002-02-14 00:00:00-05:00   1.712707   1.716074   1.670626   1.683251
# 2    2002-02-15 00:00:00-05:00   1.683250   1.687458   1.658001   1.674834
# 3    2002-02-19 00:00:00-05:00   1.666418   1.666418   1.578047   1.607504
# 4    2002-02-20 00:00:00-05:00   1.615921   1.662210   1.603296   1.662210
# ...                        ...        ...        ...        ...        ...
# 5822 2025-04-03 00:00:00-04:00  21.600000  21.780001  21.080000  21.100000
# 5823 2025-04-04 00:00:00-04:00  21.420000  23.850000  20.780001  23.490000
# 5824 2025-04-07 00:00:00-04:00  22.600000  25.020000  22.400000  24.290001
# 5825 2025-04-08 00:00:00-04:00  24.820000  24.930000  22.969999  23.389999
# 5826 2025-04-09 00:00:00-04:00  23.030001  25.459999  23.030001  25.400000
#
#         Volume  Dividends  Stock Splits
# 0     76216000        0.0           0.0
# 1     11021600        0.0           0.0
# 2      8389600        0.0           0.0
# 3      7410400        0.0           0.0
# 4      6892800        0.0           0.0
# ...        ...        ...           ...
# 5822  11141900        0.0           0.0
# 5823  20608200        0.0           0.0
# 5824  17191900        0.0           0.0
# 5825  12062300        0.0           0.0
# 5826  17630800        0.0           0.0
#
# [5827 rows x 8 columns]

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/stock.html"
html_data = requests.get(url).text
soup = BeautifulSoup(html_data, "html.parser")

tables = soup.find_all("tbody")[1]
rows = tables.find_all("tr")

gme_revenue = pd.DataFrame(columns=["Date", "Revenue"])

for row in rows:
    col = row.find_all("td")
    if col:
        date = col[0].text.strip()
        revenue = col[1].text.strip()

        new_row = pd.DataFrame([{"Date": date, "Revenue": revenue}])
        gme_revenue = pd.concat([gme_revenue, new_row], ignore_index=True)
        
gme_revenue["Revenue"] = gme_revenue['Revenue'].str.replace(',|\$',"")
gme_revenue.dropna(inplace=True)

gme_revenue = gme_revenue[gme_revenue['Revenue'] != ""]
gme_revenue.tail()
# Out:
# <>:23: SyntaxWarning:
#
# invalid escape sequence '\$'
#
# <>:23: SyntaxWarning:
#
# invalid escape sequence '\$'
#
# C:\Users\raksh\AppData\Local\Temp\ipykernel_12304\297336910.py:23: SyntaxWarning:
#
# invalid escape sequence '\$'
#           Date Revenue
# 57  2006-01-31  $1,667
# 58  2005-10-31    $534
# 59  2005-07-31    $416
# 60  2005-04-30    $475
# 61  2005-01-31    $709

# %%
import yfinance as yf
import pandas as pd
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt


def make_graph(stock_data, revenue_data, stock):
    # Clean and prepare stock data
    stock_data = stock_data[stock_data['Date'] <= '2021-06-30']

    # Clean and prepare revenue data
    revenue_data["Revenue"] = revenue_data["Revenue"].replace({'\$': '', ',': ''}, regex=True)
    revenue_data = revenue_data[revenue_data["Revenue"] != ""]
    revenue_data["Revenue"] = revenue_data["Revenue"].astype(float)
    revenue_data["Date"] = pd.to_datetime(revenue_data["Date"])
    revenue_data = revenue_data[revenue_data['Date'] <= '2021-06-30']
    revenue_data = revenue_data.sort_values("Date")

    # Plotting
    fig, ax1 = plt.subplots(figsize=(14, 6))

    ax1.plot(stock_data['Date'], stock_data['Close'], label='Stock Price', color='blue')
    ax1.set_xlabel("Date")
    ax1.set_ylabel("Stock Price of Tesla", color='blue')
    ax1.tick_params(axis='y', labelcolor='blue')

    # Add a second y-axis for revenue
    ax2 = ax1.twinx()
    ax2.plot(revenue_data['Date'], revenue_data['Revenue'], label='Revenue', color='green')
    ax2.set_ylabel("Revenue (in Millions USD)", color='green')
    ax2.tick_params(axis='y', labelcolor='green')

    plt.grid(True)
    plt.tight_layout()
    plt.show()


tesla = yf.Ticker("TSLA")
tesla_data = tsla.history(period="max")
tesla_data.reset_index(inplace=True)

url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/revenue.htm"
html_data = requests.get(url).text
soup = BeautifulSoup(html_data, "html.parser")

tables = soup.find_all("tbody")[1]
rows = tables.find_all("tr")

tesla_revenue = pd.DataFrame(columns=["Date", "Revenue"])

for row in rows:
    col = row.find_all("td")
    if col:
        date = col[0].text.strip()
        revenue = col[1].text.strip()

        new_row = pd.DataFrame([{"Date": date, "Revenue": revenue}])
        tesla_revenue = pd.concat([tesla_revenue, new_row], ignore_index=True)
        
tesla_revenue["Revenue"] = tesla_revenue['Revenue'].str.replace(',|\$',"")
tesla_revenue.dropna(inplace=True)

tesla_revenue = tesla_revenue[tesla_revenue['Revenue'] != ""]

make_graph(tesla_data, tesla_revenue, 'Tesla')
# Out:
# <>:13: SyntaxWarning:
#
# invalid escape sequence '\$'
#
# <>:61: SyntaxWarning:
#
# invalid escape sequence '\$'
#
# <>:13: SyntaxWarning:
#
# invalid escape sequence '\$'
#
# <>:61: SyntaxWarning:
#
# invalid escape sequence '\$'
#
# C:\Users\raksh\AppData\Local\Temp\ipykernel_12304\266612571.py:13: SyntaxWarning:
#
# invalid escape sequence '\$'
#
# C:\Users\raksh\AppData\Local\Temp\ipykernel_12304\266612571.py:61: SyntaxWarning:
#
# invalid escape sequence '\$'

# %%
import yfinance as yf
import pandas as pd
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt


def make_graph(stock_data, revenue_data, stock):
    # Clean and prepare stock data
    stock_data = stock_data[stock_data['Date'] <= '2021-06-30']

    # Clean and prepare revenue data
    revenue_data["Revenue"] = revenue_data["Revenue"].replace({'\$': '', ',': ''}, regex=True)
    revenue_data = revenue_data[revenue_data["Revenue"] != ""]
    revenue_data["Revenue"] = revenue_data["Revenue"].astype(float)
    revenue_data["Date"] = pd.to_datetime(revenue_data["Date"])
    revenue_data = revenue_data[revenue_data['Date'] <= '2021-06-30']
    revenue_data = revenue_data.sort_values("Date")

    # Plotting
    fig, ax1 = plt.subplots(figsize=(14, 6))

    ax1.plot(stock_data['Date'], stock_data['Close'], label='Stock Price', color='blue')
    ax1.set_xlabel("Date")
    ax1.set_ylabel("Stock Price of GameStop", color='blue')
    ax1.tick_params(axis='y', labelcolor='blue')

    # Add a second y-axis for revenue
    ax2 = ax1.twinx()
    ax2.plot(revenue_data['Date'], revenue_data['Revenue'], label='Revenue', color='green')
    ax2.set_ylabel("Revenue (in Millions USD)", color='green')
    ax2.tick_params(axis='y', labelcolor='green')

    plt.grid(True)
    plt.tight_layout()
    plt.show()


gme = yf.Ticker("GME")
gme_data = tsla.history(period="max")
gme_data.reset_index(inplace=True)

url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/stock.html"
html_data = requests.get(url).text
soup = BeautifulSoup(html_data, "html.parser")

tables = soup.find_all("tbody")[1]
rows = tables.find_all("tr")

gme_revenue = pd.DataFrame(columns=["Date", "Revenue"])

for row in rows:
    col = row.find_all("td")
    if col:
        date = col[0].text.strip()
        revenue = col[1].text.strip()

        new_row = pd.DataFrame([{"Date": date, "Revenue": revenue}])
        gme_revenue = pd.concat([gme_revenue, new_row], ignore_index=True)
        
gme_revenue["Revenue"] = gme_revenue['Revenue'].str.replace(',|\$',"")
gme_revenue.dropna(inplace=True)

gme_revenue = gme_revenue[gme_revenue['Revenue'] != ""]

make_graph(gme_data, gme_revenue, 'GameStop')
# Out:
# <>:13: SyntaxWarning:
#
# invalid escape sequence '\$'
#
# <>:61: SyntaxWarning:
#
# invalid escape sequence '\$'
#
# <>:13: SyntaxWarning:
#
# invalid escape sequence '\$'
#
# <>:61: SyntaxWarning:
#
# invalid escape sequence '\$'
#
# C:\Users\raksh\AppData\Local\Temp\ipykernel_12304\3653513268.py:13: SyntaxWarning:
#
# invalid escape sequence '\$'
#
# C:\Users\raksh\AppData\Local\Temp\ipykernel_12304\3653513268.py:61: SyntaxWarning:
#
# invalid escape sequence '\$'
